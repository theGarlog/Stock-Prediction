# %%
# import necessary modules
import quandl
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

# %%
# get stock data
df = quandl.get("WIKI/FB")
# Print data
df.head()
# Out:
#              Open   High    Low    Close       Volume  Ex-Dividend  \
# Date
# 2012-05-18  42.05  45.00  38.00  38.2318  573576400.0          0.0
# 2012-05-21  36.53  36.66  33.00  34.0300  168192700.0          0.0
# 2012-05-22  32.61  33.59  30.94  31.0000  101786600.0          0.0
# 2012-05-23  31.37  32.50  31.36  32.0000   73600000.0          0.0
# 2012-05-24  32.95  33.21  31.77  33.0300   50237200.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2012-05-18          1.0      42.05      45.00     38.00     38.2318
# 2012-05-21          1.0      36.53      36.66     33.00     34.0300
# 2012-05-22          1.0      32.61      33.59     30.94     31.0000
# 2012-05-23          1.0      31.37      32.50     31.36     32.0000
# 2012-05-24          1.0      32.95      33.21     31.77     33.0300
#
#             Adj. Volume
# Date
# 2012-05-18  573576400.0
# 2012-05-21  168192700.0
# 2012-05-22  101786600.0
# 2012-05-23   73600000.0
# ...

# %%
# Get adjusted close price
df = df[['Adj. Close']]
df.head()
# Out:
#             Adj. Close
# Date
# 2012-05-18     38.2318
# 2012-05-21     34.0300
# 2012-05-22     31.0000
# 2012-05-23     32.0000
# 2012-05-24     33.0300

# %%
# A variable for predicting 'n' days out into the future
forecast_out = 30
# create another column for dependent variable shifted 'n' units up
df['Prediction'] = df[['Adj. Close']].shift(-forecast_out)
df.head()
# Out:
#             Adj. Close  Prediction
# Date
# 2012-05-18     38.2318      30.771
# 2012-05-21     34.0300      31.200
# 2012-05-22     31.0000      31.470
# 2012-05-23     32.0000      31.730
# 2012-05-24     33.0300      32.170

# %%
# Create independent data set
# convert df to array
X = np.array(df.drop(['Prediction'],axis=1))
# remove last 'n' rows
X = X[:-forecast_out]
print(X)
# Out:
# [[ 38.2318]
#  [ 34.03  ]
#  [ 31.    ]
#  ...
#  [171.5499]
#  [175.98  ]
#  [176.41  ]]

# %%
## create dependent data set y
# convert df to array
y = np.array(df['Prediction'])
# get all y values except last n rows
y = y[:-forecast_out]
print(y)
# Out:
# [ 30.771  31.2    31.47  ... 159.39  160.06  152.19 ]

# %%
# Split data into 80% training, 20% testing
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#Create and train SVM
svr_rbf = SVR(kernel='rbf',C=1e3,gamma=0.1)
svr_rbf.fit(x_train,y_train)
# Out:
# SVR(C=1000.0, gamma=0.1)

# %%
# testing model: Score returns coeffient of determination R^2
#best is 1.0
svm_confidence =svr_rbf.score(x_test,y_test)
print(svm_confidence)
# Out:
# 0.9854084397512486

# %%
# Create and train the Linear Regression Model
lr = LinearRegression()
# train model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#test modelas above


lr_confidence =lr.score(x_test,y_test)
print(lr_confidence)
# Out:
# 0.9809874559986559

# %%
# Set x_forecast = last 30 rows of the original dataset from Adj. CLose
x_forecast = np.array(df.drop(['Prediction'],axis=1))[-forecast_out:]
print(x_forecast)
# Out:
# [[173.15]
#  [179.52]
#  [179.96]
#  [177.36]
#  [176.01]
#  [177.91]
#  [178.99]
#  [183.29]
#  [184.93]
#  [181.46]
#  [178.32]
#  [175.94]
#  [176.62]
#  [180.4 ]
#  [179.78]
#  [183.71]
#  [182.34]
#  [185.23]
#  [184.76]
#  [181.88]
#  [184.19]
#  [183.86]
#  [185.09]
#  [172.56]
#  [168.15]
#  [169.39]
#  [164.89]
#  [159.39]
#  [160.06]
#  [152.19]]

# %%
# Print the predictions for the next n days
lr_prediction = lr.predict(x_forecast)
print(lr_prediction)
svr_prediction = svr_rbf.predict(x_forecast)
print(svr_prediction)
# Out:
# [176.74378943 183.16180944 183.60512636 180.98552636 179.62534943
#  181.53967251 182.62781405 186.96022944 188.61259252 185.11643405
#  181.95276328 179.55482174 180.2399479  184.04844328 183.42376944
#  187.38339559 186.0030679  188.91485405 188.44131098 185.53960021
#  187.86701405 187.53452636 188.77379867 176.14934174 171.70609712
#  172.95544482 168.42152174 162.8800602  163.55511097 155.62578327]
# [179.96836956 181.27165453 181.58393944 175.02184126 171.65431537
#  177.36597946 180.68414602 185.72849556 179.48435603 185.36780967
#  178.95455279 171.64645936 172.4926066  182.14078315 181.44762669
#  183.71337762 187.6333976  179.4763693  179.6904371  186.78371003
#  181.41873721 182.958973   179.42571639 180.01371571 171.09895933
#  172.23094955 172.16193087 167.95276406 166.1608403  160.94198065]
